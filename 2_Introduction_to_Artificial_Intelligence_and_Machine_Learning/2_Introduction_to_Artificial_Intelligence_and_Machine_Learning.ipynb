# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Emergence-of-Artificial-Intelligence" data-toc-modified-id="Emergence-of-Artificial-Intelligence-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Emergence of Artificial Intelligence</a></span><ul class="toc-item"><li><span><a href="#Data-Economy" data-toc-modified-id="Data-Economy-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Data Economy</a></span></li><li><span><a href="#Emergence-of-Artificial-Intelligence" data-toc-modified-id="Emergence-of-Artificial-Intelligence-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Emergence of Artificial Intelligence</a></span></li><li><span><a href="#Definition-of-Artificial-Intelligence" data-toc-modified-id="Definition-of-Artificial-Intelligence-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Definition of Artificial Intelligence</a></span></li><li><span><a href="#Artificial-Intelligence-in-Practice" data-toc-modified-id="Artificial-Intelligence-in-Practice-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Artificial Intelligence in Practice</a></span></li><li><span><a href="#Sci-Fi-Movies-with-the-Concept-of-AI" data-toc-modified-id="Sci-Fi-Movies-with-the-Concept-of-AI-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Sci-Fi Movies with the Concept of AI</a></span></li><li><span><a href="#Data-Facilitates-in-Recommendations" data-toc-modified-id="Data-Facilitates-in-Recommendations-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>Data Facilitates in Recommendations</a></span></li></ul></li><li><span><a href="#Relationship-between-AI,-ML,-and-Data-Science" data-toc-modified-id="Relationship-between-AI,-ML,-and-Data-Science-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Relationship between AI, ML, and Data Science</a></span><ul class="toc-item"><li><span><a href="#Definition-of-Machine-Learning" data-toc-modified-id="Definition-of-Machine-Learning-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Definition of Machine Learning</a></span></li><li><span><a href="#Features-of-Machine-Learning" data-toc-modified-id="Features-of-Machine-Learning-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Features of Machine Learning</a></span></li></ul></li><li><span><a href="#Machine-Learning-Approach" data-toc-modified-id="Machine-Learning-Approach-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Machine Learning Approach</a></span><ul class="toc-item"><li><span><a href="#Traditional-Approach-vs.-Machine-Learning-Approach" data-toc-modified-id="Traditional-Approach-vs.-Machine-Learning-Approach-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Traditional Approach vs. Machine Learning Approach</a></span></li><li><span><a href="#Traditional-Approach" data-toc-modified-id="Traditional-Approach-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Traditional Approach</a></span></li><li><span><a href="#Machine-Learning-Approach" data-toc-modified-id="Machine-Learning-Approach-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Machine Learning Approach</a></span></li><li><span><a href="#Relationship-between-Machine-Learning-and-Data-Science" data-toc-modified-id="Relationship-between-Machine-Learning-and-Data-Science-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Relationship between Machine Learning and Data Science</a></span></li><li><span><a href="#Relationship-between-Machine-Learning-and-Data-Science" data-toc-modified-id="Relationship-between-Machine-Learning-and-Data-Science-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Relationship between Machine Learning and Data Science</a></span></li><li><span><a href="#Machine-Learning-Techniques" data-toc-modified-id="Machine-Learning-Techniques-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Machine Learning Techniques</a></span><ul class="toc-item"><li><span><a href="#Classification" data-toc-modified-id="Classification-3.6.1"><span class="toc-item-num">3.6.1&nbsp;&nbsp;</span>Classification</a></span></li><li><span><a href="#Categorization" data-toc-modified-id="Categorization-3.6.2"><span class="toc-item-num">3.6.2&nbsp;&nbsp;</span>Categorization</a></span></li><li><span><a href="#Clustering" data-toc-modified-id="Clustering-3.6.3"><span class="toc-item-num">3.6.3&nbsp;&nbsp;</span>Clustering</a></span></li><li><span><a href="#Trend-analysis" data-toc-modified-id="Trend-analysis-3.6.4"><span class="toc-item-num">3.6.4&nbsp;&nbsp;</span>Trend analysis</a></span></li><li><span><a href="#Anomaly-detection" data-toc-modified-id="Anomaly-detection-3.6.5"><span class="toc-item-num">3.6.5&nbsp;&nbsp;</span>Anomaly detection</a></span></li><li><span><a href="#Visualization" data-toc-modified-id="Visualization-3.6.6"><span class="toc-item-num">3.6.6&nbsp;&nbsp;</span>Visualization</a></span></li><li><span><a href="#Decision-making" data-toc-modified-id="Decision-making-3.6.7"><span class="toc-item-num">3.6.7&nbsp;&nbsp;</span>Decision making</a></span></li></ul></li></ul></li><li><span><a href="#Applications-of-Machine-Learning" data-toc-modified-id="Applications-of-Machine-Learning-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Applications of Machine Learning</a></span><ul class="toc-item"><li><span><a href="#Image-Processing" data-toc-modified-id="Image-Processing-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Image Processing</a></span></li><li><span><a href="#Robotics" data-toc-modified-id="Robotics-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Robotics</a></span></li><li><span><a href="#Data-Mining" data-toc-modified-id="Data-Mining-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Data Mining</a></span></li><li><span><a href="#Video-Games" data-toc-modified-id="Video-Games-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Video Games</a></span></li><li><span><a href="#Text-Analysis" data-toc-modified-id="Text-Analysis-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Text Analysis</a></span></li><li><span><a href="#Healthcare" data-toc-modified-id="Healthcare-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>Healthcare</a></span></li></ul></li></ul></div>

# %% [markdown]
# ## Emergence of Artificial Intelligence
# ### Data Economy

# %% [markdown]
# It refers to how much data has grown over the past few years and how much more it can grow in the coming years.
# ![L1_ML.PNG](attachment:L1_ML.PNG)

# %% [markdown]
# ### Emergence of Artificial Intelligence
#
# Science associated with data is going toward a new paradigm where one can teach machines to
# learn from data and derive a variety of useful insights giving rise to Artificial Intelligence.

# %% [markdown]
# ### Definition of Artificial Intelligence
# Artificial Intelligence refers to intelligence displayed by machines that
# simulates human and animal intelligence.

# %% [markdown]
# ### Artificial Intelligence in Practice
# AI is redefining industries by providing greater personalization to users and automating
# processes.
# ![L1_ML_1.PNG](attachment:L1_ML_1.PNG)

# %% [markdown]
# ### Sci-Fi Movies with the Concept of AI
# Few AI films spanned through the decades that reflect the everchanging spectrum of our
# emotions regarding the machines we have created
# ![L1_ML_2.PNG](attachment:L1_ML_2.PNG)

# %% [markdown]
# ### Data Facilitates in Recommendations
# Amazon collects data from users and recommends the best products according to the user's
# buying/shopping pattern.
#
# ![L1_ML_3.PNG](attachment:L1_ML_3.PNG)

# %% [markdown]
# ## Relationship between AI, ML, and Data Science
# Even though the terms data science, machine learning, and artificial intelligence (AI) fall in the same domain and are
# connected to each other, they have their specific applications and meaning.
# ![L1_ML_4.PNG](attachment:L1_ML_4.PNG)

# %% [markdown]
# ![L1_ML_5.PNG](attachment:L1_ML_5.PNG)

# %% [markdown]
# ### Definition of Machine Learning
# The capability of Artificial Intelligence systems to learn by extracting patterns
# from data is known as Machine Learning.
#
# ### Features of Machine Learning
# ![L1_ML_6.PNG](attachment:L1_ML_6.PNG)

# %% [markdown]
# ## Machine Learning Approach
# ### Traditional Approach vs. Machine Learning Approach
# ![L1_ML_7.PNG](attachment:L1_ML_7.PNG)

# %% [markdown]
# ### Traditional Approach
# ![L1_ML_8.PNG](attachment:L1_ML_8.PNG)

# %% [markdown]
# ### Machine Learning Approach
# ![L1_ML_9.PNG](attachment:L1_ML_9.PNG)
#
# ### Relationship between Machine Learning and Data Science
# Data Science and Machine Learning go hand in hand. Data
# Science helps evaluate data for Machine Learning algorithms.

# %% [markdown]
# ### Relationship between Machine Learning and Data Science
# ![L1_ML_10.PNG](attachment:L1_ML_10.PNG)

# %% [markdown]
# ### Machine Learning Techniques
# ![L1_ML_11.PNG](attachment:L1_ML_11.PNG)

# %% [markdown]
# #### Classification
# Classification is a technique in
# which the computer program
# learns from the data input
# given to it and then uses
# this learning to classify new
# observation

# %% [markdown]
# #### Categorization
# A technique of
# organizing data into categories
# for its most effective and
# efficient use.

# %% [markdown]
# #### Clustering
# Technique of grouping a set of
# objects in such a way that
# objects in the same group are
# more similar to each other than
# to those in other groups

# %% [markdown]
# #### Trend analysis
# Trend Analysis is a technique
# aimed at projecting both
# current and future movement
# of events through use of time
# series data analysis

# %% [markdown]
# #### Anomaly detection
# Anomaly detection is a
# technique to identify cases that
# are unusual within data that is
# seemingly homogeneous

# %% [markdown]
# #### Visualization
# Technique to present data in a
# pictorial or graphical format. It
# enables decision makers to
# see analytics presented visually

# %% [markdown]
# #### Decision making
# A technique/skill which
# provides you with the ability to
# influence managerial decisions
# with data as evidence for those
# possibilities

# %% [markdown]
# ## Applications of Machine Learning
# Artificial intelligence and Machine learning are being increasingly used in various functions such as:
# ![L1_ML_12.PNG](attachment:L1_ML_12.PNG)

# %% [markdown]
# ### Image Processing
# * Image tagging and recognition
# * Self-driving cars
# * Optical Character Recognition (OCR)
#
# ### Robotics
# * Human simulation
# * Humanoid Robot
# * Industrial robotics
#
# ### Data Mining
# * Anomaly detection
# * Grouping and Predictions
# * Association rules in e-commerce websites
#
# ### Video Games
# * Some games implement reinforcement learning
#
# ### Text Analysis
# * Sentiment Analysis
# * Spam Filtering
# * Information Extraction
#
# ### Healthcare
# * Patient Data & Risk Analysis
# * Virtual Assistance
# * Drug Discovery
# * Medical Imaging and Diagnosis
# * Wearables
